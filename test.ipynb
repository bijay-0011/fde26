# %%
from config_loader import CONFIG
print(CONFIG)
# Out:
# {'simulation': {'sim_speed': 3600, 'preload_watermark': '2017-01-15 00:00:00', 'data_dir': './data'}, 'database': {'oltp': {'host': 'localhost', 'port': '5432', 'name': 'oltp_db', 'user': 'vijay', 'password': 'postgrespass'}, 'analytics': {'host': 'localhost', 'port': '5432', 'name': 'analytics_db', 'user': 'vijay', 'password': 'postgrespass'}}, 'pgadmin': {'email': 'bijaya.ghimire@heraldcollege.edu.np', 'password': 'pgadminpass'}, 'api': {'fastapi_url': 'http://localhost:8000'}, 'storage': {'minio_endpoint': 'http://localhost:9090', 'minio_root_user': 'admin', 'minio_root_password': 'miniopass', 'minio_access_key': 'DOdHtdJKagvfqTTavNh8', 'minio_secret_key': 'y29cLQIps0gu0Mb3jnM0ocHmzPH7pFZMBoo5rvJf', 'shared_bucket': 'pay_review'}, 'datasets': {'orders': 'olist_orders_dataset.csv', 'items': 'olist_order_items_dataset.csv', 'payments': 'olist_order_payments_dataset.csv', 'reviews': 'olist_order_reviews_dataset.csv', 'master_tables': {'customers': 'olist_customers_dataset.csv', 'prod
# ...
